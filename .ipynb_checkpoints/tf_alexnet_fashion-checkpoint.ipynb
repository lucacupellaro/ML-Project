# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# Let's start by loading the fashion MNIST dataset.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
X_train_full = X_train_full.reshape(-1,28,28,1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# The training set contains 60,000 grayscale images, each 28x28 pixels:

# %%
X_train_full.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# Let's split the full training set into a validation set and a (smaller) training set. We also scale the pixel intensities down to the 0-1 range and convert them to floats, by dividing by 255.

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %% [markdown]
# The labels are the class IDs (represented as uint8), from 0 to 9:

# %%
y_train
# Out:
# array([4, 0, 7, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# Here are the corresponding class names:

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# ## AlexNet

# %%
alex = tf.keras.models.Sequential([
            tf.keras.layers.Resizing(227,227), # just an example, do not upscale input in practice!
            tf.keras.layers.Conv2D(filters=96, kernel_size=11, strides=4,
                                   activation='relu'),
            keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
            tf.keras.layers.Conv2D(filters=256, kernel_size=5, padding='same',
                                   activation='relu'),
            keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
            tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                                   activation='relu'),
            keras.layers.BatchNormalization(),
            tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                                   activation='relu'),
            keras.layers.BatchNormalization(),
            tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                                   activation='relu'),
            keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(10, activation="softmax")])


alex.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %%
historyA = alex.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 117s 57ms/step - accuracy: 0.5818 - loss: 2.7992 - val_accuracy: 0.6270 - val_loss: 0.9858
# Epoch 2/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 126s 53ms/step - accuracy: 0.6120 - loss: 1.0172 - val_accuracy: 0.7458 - val_loss: 0.7049
# Epoch 3/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 144s 55ms/step - accuracy: 0.6690 - loss: 0.8419 - val_accuracy: 0.7550 - val_loss: 0.6109
# Epoch 4/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 94s 55ms/step - accuracy: 0.7190 - loss: 0.6935 - val_accuracy: 0.7736 - val_loss: 0.5890
# Epoch 5/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 141s 54ms/step - accuracy: 0.7436 - loss: 0.6008 - val_accuracy: 0.8012 - val_loss: 0.5034
# Epoch 6/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.7885 - loss: 0.5197 - val_accuracy: 0.8536 - val_loss: 0.3709
# Epoch 7/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.8663 - loss: 0.3803 - val_accuracy: 0.8932 - val_loss: 0.2933
# Epoch 8/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 93s 54ms/step - accuracy: 0.8876 - loss: 0.3210 - val_accuracy: 0.8940 - val_loss: 0.2901
# Epoch 9/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.8983 - loss: 0.2861 - val_accuracy: 0.9060 - val_loss: 0.2708
# Epoch 10/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.9062 - loss: 0.2722 - val_accuracy: 0.9108 - val_loss: 0.2565
# Epoch 11/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.9120 - loss: 0.2512 - val_accuracy: 0.9170 - val_loss: 0.2476
# Epoch 12/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.9174 - loss: 0.2421 - val_accuracy: 0.9112 - val_loss: 0.2487
# Epoch 13/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 93s 54ms/step - accuracy: 0.9184 - loss: 0.2396 - val_accuracy: 0.9146 - val_loss: 0.2432
# Epoch 14/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 94s 55ms/step - accuracy: 0.9189 - loss: 0.2382 - val_accuracy: 0.9108 - val_loss: 0.2536
# Epoch 15/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 140s 54ms/step - accuracy: 0.9281 - loss: 0.2143 - val_accuracy: 0.9214 - val_loss: 0.2782
# Epoch 16/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 53ms/step - accuracy: 0.9285 - loss: 0.2099 - val_accuracy: 0.9120 - val_loss: 0.3009
# Epoch 17/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 92s 54ms/step - accuracy: 0.9300 - loss: 0.2027 - val_accuracy: 0.9078 - val_loss: 0.2999
# Epoch 18/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 142s 54ms/step - accuracy: 0.9302 - loss: 0.2146 - val_accuracy: 0.9142 - val_loss: 0.2846
# Epoch 19/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 143s 55ms/step - accuracy: 0.9344 - loss: 0.1929 - val_accuracy: 0.9126 - val_loss: 0.2774
# Epoch 20/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 141s 54ms/step - accuracy: 0.9394 - loss: 0.1784 - val_accuracy: 0.9150 - val_loss: 0.2990

# %%
import pandas as pd

pd.DataFrame(historyA.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()
